# %% [markdown]
# # DataFrames.jl 介紹 (二): Joins 與 Split-Apply-Combine Strategy
#
# ## Day 018 作業1：The Split-Apply-Combine Strategy
#
# 同 Day 017，請載入 2020/4/2 COVID-19 Daily Report 資料集，計算每個國家/地區的累計確診人數，並列出所有資料筆數。

# %%
using DataFrames, CSV

# %%
df = CSV.read("Day_018_04-02-2020.csv")
# Out:
# 2569×12 DataFrame. Omitted printing of 8 columns
# │ Row  │ FIPS    │ Admin2     │ Province_State │ Country_Region       │
# │      │ Int64⍰  │ String⍰    │ String⍰        │ String               │
# ├──────┼─────────┼────────────┼────────────────┼──────────────────────┤
# │ 1    │ 45001   │ Abbeville  │ South Carolina │ US                   │
# │ 2    │ 22001   │ Acadia     │ Louisiana      │ US                   │
# │ 3    │ 51001   │ Accomack   │ Virginia       │ US                   │
# │ 4    │ 16001   │ Ada        │ Idaho          │ US                   │
# │ 5    │ 19001   │ Adair      │ Iowa           │ US                   │
# │ 6    │ 29001   │ Adair      │ Missouri       │ US                   │
# │ 7    │ 40001   │ Adair      │ Oklahoma       │ US                   │
# │ 8    │ 8001    │ Adams      │ Colorado       │ US                   │
# │ 9    │ 16003   │ Adams      │ Idaho          │ US                   │
# │ 10   │ 17001   │ Adams      │ Illinois       │ US                   │
# ⋮
# │ 2559 │ missing │ missing    │ missing        │ Ukraine              │
# │ 2560 │ missing │ missing    │ missing        │ United Arab Emirates │
# │ 2561 │ missing │ missing    │ missing        │ United Kingdom       │
# │ 2562 │ missing │ missing    │ missing        │ Uruguay              │
# │ 2563 │ missing │ missing    │ missing        │ Uzbekistan           │
# │ 2564 │ missing │ missing    │ missing        │ Venezuela            │
# │ 2565 │ missing │ missing    │ missing        │ Vietnam              │
# │ 2566 │ missing │ missing    │ missing        │ West Bank and Gaza   │
# │ 2567 │ missing │ missing    │ missing        │ Zambia               │
# │ 2568 │ missing │ missing    │ missing        │ Zimbabwe             │
# │ 2569 │ missing │ unassigned │ Wyoming        │ US                   │

# %% [markdown]
# 計算計算每個國家/地區的累計確診人數
#
# 【提示】可使用 groupby 相關的函式

# %%
gdf=groupby(df, :Country_Region)
# Out:
# GroupedDataFrame with 181 groups based on key: Country_Region
# First Group (2312 rows): Country_Region = "US". Omitted printing of 8 columns
# │ Row  │ FIPS    │ Admin2     │ Province_State           │ Country_Region │
# │      │ Int64⍰  │ String⍰    │ Union{Missing, String}   │ String         │
# ├──────┼─────────┼────────────┼──────────────────────────┼────────────────┤
# │ 1    │ 45001   │ Abbeville  │ South Carolina           │ US             │
# │ 2    │ 22001   │ Acadia     │ Louisiana                │ US             │
# │ 3    │ 51001   │ Accomack   │ Virginia                 │ US             │
# │ 4    │ 16001   │ Ada        │ Idaho                    │ US             │
# │ 5    │ 19001   │ Adair      │ Iowa                     │ US             │
# │ 6    │ 29001   │ Adair      │ Missouri                 │ US             │
# │ 7    │ 40001   │ Adair      │ Oklahoma                 │ US             │
# │ 8    │ 8001    │ Adams      │ Colorado                 │ US             │
# │ 9    │ 16003   │ Adams      │ Idaho                    │ US             │
# │ 10   │ 17001   │ Adams      │ Illinois                 │ US             │
# ⋮
# │ 2302 │ 6115    │ Yuba       │ California               │ US             │
# │ 2303 │ 4027    │ Yuma       │ Arizona                  │ US             │
# │ 2304 │ 8125    │ Yuma       │ Colorado                 │ US             │
# │ 2305 │ 88888   │ missing    │ Diamond Princess         │ US             │
# │ 2306 │ 99999   │ missing    │ Grand Princess           │ US             │
# │ 2307 │ 66      │ missing    │ Guam                     │ US             │
# │ 2308 │ missing │ missing    │ Northern Mariana Islands │ US             │
# │ 2309 │ 72      │ missing    │ Puerto Rico              │ US             │
# │ 2310 │ missing │ missing    │ Recovered                │ US             │
# │ 2311 │ 78      │ missing    │ Virgin Islands           │ US             │
# │ 2312 │ missing │ unassigned │ Wyoming                  │ US             │
# ⋮
# Last Group (1 row): Country_Region = "Zimbabwe". Omitted printing of 7 columns
# │ Row │ FIPS    │ Admin2  │ Province_State │ Country_Region │ Last_Update  │
# │     │ Int64⍰  │ String⍰ │ String⍰        │ String         │ String       │
# ├─────┼─────────┼─────────┼────────────────┼────────────────┼──────────────┤
# │ 1   │ missing │ missing │ missing        │ Zimbabwe       │ 4/2/20 23:25 │

# %%
# 顯示所有資料
for i ∈ gdf
    s=sum(i.Confirmed)
    println("$(first(i.Country_Region)): $s")
end
# Out:
# US: 243599
# Canada: 11284
# United Kingdom: 34173
# China: 82432
# Netherlands: 14788
# Australia: 5116
# Denmark: 3573
# France: 59929
# Afghanistan: 273
# Albania: 277
# Algeria: 986
# Andorra: 428
# Angola: 8
# Antigua and Barbuda: 9
# Argentina: 1133
# Armenia: 663
# Austria: 11129
# Azerbaijan: 400
# Bahamas: 24
# Bahrain: 643
# Bangladesh: 56
# Barbados: 46
# Belarus: 304
# Belgium: 15348
# Belize: 3
# Benin: 13
# Bhutan: 5
# Bolivia: 123
# Bosnia and Herzegovina: 533
# Botswana: 4
# Brazil: 8044
# Brunei: 133
# Bulgaria: 457
# Burkina Faso: 288
# Burma: 20
# Burundi: 3
# Cabo Verde: 6
# Cambodia: 110
# Cameroon: 306
# Central African Republic: 3
# Chad: 8
# Chile: 3404
# Colombia: 1161
# Congo (Brazzaville): 22
# Congo (Kinshasa): 134
# Costa Rica: 396
# Cote d'Ivoire: 194
# Croatia: 1011
# Cuba: 233
# Cyprus: 356
# Czechia: 3858
# Diamond Princess: 712
# Djibouti: 40
# Dominica: 12
# Dominican Republic: 1380
# Ecuador: 3163
# Egypt: 865
# El Salvador: 41
# Equatorial Guinea: 15
# Eritrea: 22
# Estonia: 858
# Eswatini: 9
# Ethiopia: 29
# Fiji: 7
# Finland: 1518
# Gabon: 21
# Gambia: 4
# Georgia: 134
# Germany: 84794
# Ghana: 204
# Greece: 1544
# Grenada: 10
# Guatemala: 47
# Guinea: 52
# Guinea-Bissau: 9
# Guyana: 19
# Haiti: 16
# Holy See: 7
# Honduras: 219
# Hungary: 585
# Iceland: 1319
# India: 2543
# Indonesia: 1790
# Iran: 50468
# Iraq: 772
# Ireland: 3849
# Israel: 6857
# Italy: 115242
# Jamaica: 47
# Japan: 2495
# Jordan: 299
# Kazakhstan: 435
# Kenya: 110
# Korea, South: 9976
# Kosovo: 125
# Kuwait: 342
# Kyrgyzstan: 116
# Laos: 10
# Latvia: 458
# Lebanon: 494
# Liberia: 6
# Libya: 11
# Liechtenstein: 75
# Lithuania: 649
# Luxembourg: 2487
# MS Zaandam: 9
# Madagascar: 59
# Malawi: 3
# Malaysia: 3116
# Maldives: 19
# Mali: 36
# Malta: 196
# Mauritania: 6
# Mauritius: 169
# Mexico: 1378
# Moldova: 505
# Monaco: 60
# Mongolia: 14
# Montenegro: 144
# Morocco: 708
# Mozambique: 10
# Namibia: 14
# Nepal: 6
# New Zealand: 797
# Nicaragua: 5
# Niger: 98
# Nigeria: 184
# North Macedonia: 384
# Norway: 5147
# Oman: 231
# Pakistan: 2421
# Panama: 1317
# Papua New Guinea: 1
# Paraguay: 77
# Peru: 1414
# Philippines: 2633
# Poland: 2946
# Portugal: 9034
# Qatar: 949
# Romania: 2738
# Russia: 3548
# Rwanda: 84
# Saint Kitts and Nevis: 9
# Saint Lucia: 13
# Saint Vincent and the Grenadines: 2
# San Marino: 245
# Saudi Arabia: 1885
# Senegal: 195
# Serbia: 1171
# Seychelles: 10
# Sierra Leone: 2
# Singapore: 1049
# Slovakia: 426
# Slovenia: 897
# Somalia: 5
# South Africa: 1462
# Spain: 112065
# Sri Lanka: 151
# Sudan: 8
# Suriname: 10
# Sweden: 5568
# Switzerland: 18827
# Syria: 16
# Taiwan*: 339
# Tanzania: 20
# Thailand: 1875
# Timor-Leste: 1
# Togo: 39
# Trinidad and Tobago: 94
# Tunisia: 455
# Turkey: 18135
# Uganda: 45
# Ukraine: 897
# United Arab Emirates: 1024
# Uruguay: 350
# Uzbekistan: 205
# Venezuela: 146
# Vietnam: 233
# West Bank and Gaza: 161
# Zambia: 39
# Zimbabwe: 9

# %% [markdown]
# ## 作業2：請列出美國各區域或事件 (依 Province_State 欄) 的累積確診、死亡、康復人數。
#
# 【提示】使用 Split-Apply-Combine Strategy 時，有幾種不同的函式可以使用，請參照 `DataFrames.jl` 官方文件 [https://juliadata.github.io/DataFrames.jl/stable/lib/functions/#DataFrames.groupby](https://juliadata.github.io/DataFrames.jl/stable/lib/functions/#DataFrames.groupby)

# %%
sort(by(df[df.Country_Region .== "US", :], :Province_State, (:Confirmed => sum, :Deaths => sum, :Recovered => sum)), :Confirmed_sum, rev=true)
# Out:
# 58×4 DataFrame
# │ Row │ Province_State           │ Confirmed_sum │ Deaths_sum │ Recovered_sum │
# │     │ Union{Missing, String}   │ Int64         │ Int64      │ Int64         │
# ├─────┼──────────────────────────┼───────────────┼────────────┼───────────────┤
# │ 1   │ New York                 │ 92506         │ 2373       │ 0             │
# │ 2   │ New Jersey               │ 25590         │ 537        │ 0             │
# │ 3   │ Michigan                 │ 10791         │ 417        │ 0             │
# │ 4   │ California               │ 10773         │ 238        │ 0             │
# │ 5   │ Louisiana                │ 9149          │ 310        │ 0             │
# │ 6   │ Florida                  │ 9008          │ 164        │ 0             │
# │ 7   │ Massachusetts            │ 8966          │ 154        │ 0             │
# │ 8   │ Illinois                 │ 7695          │ 163        │ 0             │
# │ 9   │ Pennsylvania             │ 7268          │ 90         │ 0             │
# │ 10  │ Washington               │ 6389          │ 271        │ 0             │
# ⋮
# │ 48  │ West Virginia            │ 216           │ 2          │ 0             │
# │ 49  │ South Dakota             │ 165           │ 2          │ 0             │
# │ 50  │ North Dakota             │ 159           │ 3          │ 0             │
# │ 51  │ Wyoming                  │ 150           │ 0          │ 0             │
# │ 52  │ Alaska                   │ 143           │ 3          │ 0             │
# │ 53  │ Grand Princess           │ 103           │ 3          │ 0             │
# │ 54  │ Guam                     │ 82            │ 3          │ 0             │
# │ 55  │ Diamond Princess         │ 49            │ 0          │ 0             │
# │ 56  │ Virgin Islands           │ 30            │ 0          │ 0             │
# │ 57  │ Northern Mariana Islands │ 6             │ 1          │ 0             │
# │ 58  │ Recovered                │ 0             │ 0          │ 9001          │
